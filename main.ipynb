# %%
import pandas as pd
data1 = pd.read_csv("temp.csv", encoding = 'unicode_escape')
data2 = pd.read_csv("temp1.csv", encoding = 'unicode_escape')
data3 = pd.read_csv("temp2.csv", encoding = 'unicode_escape')
data4 = pd.read_csv("temp3.csv", encoding = 'unicode_escape')

# %%
result = data2.append(data3)
harshil = result.append(data4)

# %%
harshil
# Out:
#         Latitude    Longitude  Elevation Stream Bed Material   Lithology
# 0      27°00'15"    76°00'33"        409       Aeol,All,Clay  Undiff.Sd.
# 1      27°00'19"    76°00'53"        394       Aeol,All,Clay  Undiff.Sd.
# 2      27°00'44"    76°00'07"        389       Aeol,All,Clay  Undiff.Sd.
# 3      27°00'59"    76°01'02"        406       Aeol,All,Clay  Undiff.Sd.
# 4      27°00'11"    76°01'29"        396       Aeol,All,Clay  Undiff.Sd.
# ..           ...          ...        ...                 ...         ...
# 505  27°29'24.2"  76°02'16.8"        440                  Sd  Undiff.Sd.
# 506  27°29'32.2"  76°01'24.6"        460                  Sd  Undiff.Sd.
# 507  27°29'42.6"  76°02'06.1"        452                  Sd  Undiff.Sd.
# 508  27°29'45.0"  76°02'34.1"        459                  Sd  Undiff.Sd.
# 509  27°29'26.6"  76°03'18.2"        466                  Sd  Undiff.Sd.
#
# [1908 rows x 5 columns]

# %%
for j in range(harshil.shape[0]):
   harshil.iloc[j,0]=int(harshil.iloc[j,0].split("°")[0])*60*60+int(harshil.iloc[j,0].split("°")[1].split("'")[0])*60+float(harshil.iloc[j,0].split("°")[1].split("'")[1].split('"')[0])

# %%
#converted longitude into seconds
for i in range(harshil.shape[0]):
   harshil.iloc[i,1]=int(harshil.iloc[i,1].split("°")[0])*60*60+int(harshil.iloc[i,1].split("°")[1].split("'")[0])*60+float(harshil.iloc[i,1].split("°")[1].split("'")[1].split('"')[0])

# %%
harshil.head()
# Out:
#   Latitude Longitude  Elevation Stream Bed Material   Lithology
# 0  97215.0  273633.0        409       Aeol,All,Clay  Undiff.Sd.
# 1  97219.0  273653.0        394       Aeol,All,Clay  Undiff.Sd.
# 2  97244.0  273607.0        389       Aeol,All,Clay  Undiff.Sd.
# 3  97259.0  273662.0        406       Aeol,All,Clay  Undiff.Sd.
# 4  97211.0  273689.0        396       Aeol,All,Clay  Undiff.Sd.

# %%
from sklearn.preprocessing import MinMaxScaler
mnc=MinMaxScaler()

mnc.fit(harshil[["Latitude","Longitude"]])
harshil[["Latitude","Longitude"]]=100*mnc.transform(harshil[["Latitude","Longitude"]])

# %%
harshil
# Out:
#       Latitude  Longitude  Elevation Stream Bed Material   Lithology
# 0     0.754907   1.686425        409       Aeol,All,Clay  Undiff.Sd.
# 1     0.978583   2.799577        394       Aeol,All,Clay  Undiff.Sd.
# 2     2.376559   0.239328        389       Aeol,All,Clay  Undiff.Sd.
# 3     3.215344   3.300495        406       Aeol,All,Clay  Undiff.Sd.
# 4     0.531231   4.803250        396       Aeol,All,Clay  Undiff.Sd.
# ..         ...        ...        ...                 ...         ...
# 505  98.568473   7.463683        440                  Sd  Undiff.Sd.
# 506  99.015825   4.558357        460                  Sd  Undiff.Sd.
# 507  99.597383   6.868147        452                  Sd  Undiff.Sd.
# 508  99.731589   8.426560        459                  Sd  Undiff.Sd.
# 509  98.702679  10.881060        466                  Sd  Undiff.Sd.
#
# [1908 rows x 5 columns]

# %%
for j in range(harshil.shape[0]):
  #if("," in harshil.iloc[j,3]):
  harshil.iloc[j,3]=(harshil.iloc[j,3].split(",")[0])
  harshil.iloc[j,3]=(harshil.iloc[j,3].split(".")[0])
  harshil.iloc[j,3]=(harshil.iloc[j,3].split(" ")[0])
  harshil.iloc[j,3]=(harshil.iloc[j,3].split("(")[0])
  harshil.iloc[j,3]=(harshil.iloc[j,3].split("!")[0])
  harshil.iloc[j,3]=(harshil.iloc[j,3].split("-")[0])
  harshil.iloc[j,3]=(harshil.iloc[j,3].split("/")[0])
  harshil.iloc[j,3]=harshil.iloc[j,3].lower()

# %%
for j in range(harshil.shape[0]):
  #if("," in harshil.iloc[j,3]):
  harshil.iloc[j,4]=(harshil.iloc[j,4].split(",")[0])
  harshil.iloc[j,4]=(harshil.iloc[j,4].split(".")[0])
  harshil.iloc[j,4]=(harshil.iloc[j,4].split(" ")[0])
  harshil.iloc[j,4]=(harshil.iloc[j,4].split("(")[0])
  harshil.iloc[j,4]=(harshil.iloc[j,4].split("!")[0])
  harshil.iloc[j,4]=(harshil.iloc[j,4].split("-")[0])
  harshil.iloc[j,4]=(harshil.iloc[j,4].split("/")[0])
  harshil.iloc[j,4]=harshil.iloc[j,4].lower()

# %%
harshil.head()
# Out:
#    Latitude  Longitude  Elevation Stream Bed Material Lithology
# 0  0.754907   1.686425        409                aeol    undiff
# 1  0.978583   2.799577        394                aeol    undiff
# 2  2.376559   0.239328        389                aeol    undiff
# 3  3.215344   3.300495        406                aeol    undiff
# 4  0.531231   4.803250        396                aeol    undiff

# %%
data1
# Out:
#      Unnamed: 0   Latitude  Longitude  Elevation Stream Bed Material  \
# 0             0  27.809002  54.098924         14                clay
# 1             1  26.153118  57.366401          8           siltyclay
# 2             3  25.541980  98.779794         11           siltyclay
# 3             4  29.670846   1.294362         14           siltysand
# 4             5  31.639996   6.330238         16           siltysand
# ..          ...        ...        ...        ...                 ...
# 467         468  14.791152   9.414683          3           siltyclay
# 468         469  16.462879  21.835499          8           siltyclay
# 469         470  15.700613  29.371111          7           siltyclay
# 470         471  14.573394  31.676805          5           siltysand
# 471         472  15.836796  40.564306          8           siltyclay
#
#                  Lithology
# 0                 Laterite
# 1                 Laterite
# 2    Rajahmundry Sandstone
# ...

# %%
data1 = data1.drop(['Unnamed: 0'],axis=1)

# %%
data1
# Out:
#       Latitude  Longitude  Elevation Stream Bed Material  \
# 0    27.809002  54.098924         14                clay
# 1    26.153118  57.366401          8           siltyclay
# 2    25.541980  98.779794         11           siltyclay
# 3    29.670846   1.294362         14           siltysand
# 4    31.639996   6.330238         16           siltysand
# ..         ...        ...        ...                 ...
# 467  14.791152   9.414683          3           siltyclay
# 468  16.462879  21.835499          8           siltyclay
# 469  15.700613  29.371111          7           siltyclay
# 470  14.573394  31.676805          5           siltysand
# 471  15.836796  40.564306          8           siltyclay
#
#                  Lithology
# 0                 Laterite
# 1                 Laterite
# 2    Rajahmundry Sandstone
# 3    Rajahmundry Sandstone
# 4    Rajahmundry Sandstone
# ..                     ...
# 467          Kaikalur clay
# 468          Kaikalur clay
# ...

# %%
harshil
# Out:
#       Latitude  Longitude  Elevation Stream Bed Material Lithology
# 0     0.754907   1.686425        409                aeol    undiff
# 1     0.978583   2.799577        394                aeol    undiff
# 2     2.376559   0.239328        389                aeol    undiff
# 3     3.215344   3.300495        406                aeol    undiff
# 4     0.531231   4.803250        396                aeol    undiff
# ..         ...        ...        ...                 ...       ...
# 505  98.568473   7.463683        440                  sd    undiff
# 506  99.015825   4.558357        460                  sd    undiff
# 507  99.597383   6.868147        452                  sd    undiff
# 508  99.731589   8.426560        459                  sd    undiff
# 509  98.702679  10.881060        466                  sd    undiff
#
# [1908 rows x 5 columns]

# %%
df = harshil.append(data1)

# %%
df.reset_index(inplace = True, drop = True)

# %%
df
# Out:
#        Latitude  Longitude  Elevation Stream Bed Material      Lithology
# 0      0.754907   1.686425        409                aeol         undiff
# 1      0.978583   2.799577        394                aeol         undiff
# 2      2.376559   0.239328        389                aeol         undiff
# 3      3.215344   3.300495        406                aeol         undiff
# 4      0.531231   4.803250        396                aeol         undiff
# ...         ...        ...        ...                 ...            ...
# 2375  14.791152   9.414683          3           siltyclay  Kaikalur clay
# 2376  16.462879  21.835499          8           siltyclay  Kaikalur clay
# 2377  15.700613  29.371111          7           siltyclay  Kaikalur clay
# 2378  14.573394  31.676805          5           siltysand  Kaikalur clay
# 2379  15.836796  40.564306          8           siltyclay  Kaikalur clay
#
# [2380 rows x 5 columns]

# %%
from sklearn.preprocessing import LabelEncoder
le=LabelEncoder()
df['Stream Bed Material']=le.fit_transform(df['Stream Bed Material'])

# %%
df.drop(df[(df['Lithology'] =='brecc')].index, inplace=True)
df.drop(df[(df['Lithology'] =='marb')].index, inplace=True)
df.drop(df[(df['Lithology'] =='mica')].index, inplace=True)
df.drop(df[(df['Lithology'] =='l')].index, inplace=True)
df.drop(df[(df['Lithology'] =='schist')].index, inplace=True)
df.drop(df[(df['Lithology'] =='brecciated')].index, inplace=True)
df.drop(df[(df['Lithology'] =='qtz')].index, inplace=True)
df.drop(df[(df['Lithology'] =='fine')].index, inplace=True)
df.drop(df[(df['Lithology'] =='pebbly')].index, inplace=True)
df.drop(df[(df['Lithology'] =='amphibole')].index, inplace=True)
df.drop(df[(df['Lithology'] =='malachite')].index, inplace=True)
df.drop(df[(df['Lithology'] =='amphibolite')].index, inplace=True)
df.drop(df[(df['Lithology'] =='thick')].index, inplace=True)
df.drop(df[(df['Lithology'] =='sericite')].index, inplace=True)
df.drop(df[(df['Lithology'] =='kanker')].index, inplace=True)
df.drop(df[(df['Lithology'] =='boulders')].index, inplace=True)
df.drop(df[(df['Lithology'] =='metabasics')].index, inplace=True)
df.drop(df[(df['Lithology'] =='sd')].index, inplace=True)
df.drop(df[(df['Lithology'] =='carbonate')].index, inplace=True)
df.drop(df[(df['Lithology'] =='ferriuginous')].index, inplace=True)
df.drop(df[(df['Lithology'] =='bgc')].index, inplace=True)
df.drop(df[(df['Lithology'] =='quartz')].index, inplace=True)
df.drop(df[(df['Lithology'] =='metabasics')].index, inplace=True)
df.drop(df[(df['Lithology'] =='metabasic')].index, inplace=True)
df.drop(df[(df['Lithology'] =='micaceous')].index, inplace=True)
df.drop(df[(df['Lithology'] =='gneissic')].index, inplace=True)
df.drop(df[(df['Lithology'] =='schi')].index, inplace=True)
df.drop(df[(df['Lithology'] =='calc')].index, inplace=True)
df.drop(df[(df['Lithology'] =='alluvium')].index, inplace=True)
df.drop(df[(df['Lithology'] =='gneiss')].index, inplace=True)
df.drop(df[(df['Lithology'] =='weathered')].index, inplace=True)
df.drop(df[(df['Lithology'] =='gritty')].index, inplace=True)
df.drop(df[(df['Lithology'] =='dolomitic')].index, inplace=True)
df.drop(df[(df['Lithology'] =='carb')].index, inplace=True)

# %%
df
# Out:
#        Latitude  Longitude  Elevation  Stream Bed Material      Lithology
# 0      0.754907   1.686425        409                    0         undiff
# 1      0.978583   2.799577        394                    0         undiff
# 2      2.376559   0.239328        389                    0         undiff
# 3      3.215344   3.300495        406                    0         undiff
# 4      0.531231   4.803250        396                    0         undiff
# ...         ...        ...        ...                  ...            ...
# 2375  14.791152   9.414683          3                    9  Kaikalur clay
# 2376  16.462879  21.835499          8                    9  Kaikalur clay
# 2377  15.700613  29.371111          7                    9  Kaikalur clay
# 2378  14.573394  31.676805          5                   10  Kaikalur clay
# 2379  15.836796  40.564306          8                    9  Kaikalur clay
#
# [2284 rows x 5 columns]

# %%
import numpy as np
df['Lithology'] = np.where(df['Lithology'] =="dolo", "dolomite", df['Lithology'])
df['Lithology'] = np.where(df['Lithology'] =="gran", "granite", df['Lithology'])

# %%
X=df.iloc[:,0:-1]
y=df.iloc[:,-1]

# %%
from sklearn.model_selection import train_test_split
X_train, X_test, y_train, y_test = train_test_split(
    X, y, test_size=0.22, random_state=40)
print("Shape of X_train = ", X_train.shape)
print("Shape of X_test = ", X_test.shape)
print("Shape of y_train = ", y_train.shape)
print("Shape of y_test = ", y_train.shape)
# Out:
# Shape of X_train =  (1781, 4)
# Shape of X_test =  (503, 4)
# Shape of y_train =  (1781,)
# Shape of y_test =  (1781,)

# %%
data={"Latitude":[26.032], 
      "Longitude":[55],
      "Elevation (in m)":[10],
      "Stream Bed Material":[2]
}
pre=pd.DataFrame(data)

# %%
import seaborn as sns
sns.set_style(style="ticks")
sns.set_palette("husl")
sns.pairplot(df.iloc[:,0:6],hue="Lithology")

# %%
from sklearn.ensemble import RandomForestClassifier
classifier=RandomForestClassifier()
classifier.fit(X_train,y_train)
# Out:
# RandomForestClassifier()

# %%
classifier.score(X_test,y_test)
# Out:
# 0.8349900596421471

# %%
import seaborn as sns
import numpy as np
import matplotlib.pyplot as plt
from PIL import Image
def Mineral_probability(Latitude, Longitude, Elevation, Stream_Bed_Material):
  data={"Latitude":[Latitude],
        "Longitude":[Longitude],
        "Elevation (in m)":[Elevation],
        "Stream Bed Material": [Stream_Bed_Material]
  }
  pre=pd.DataFrame(data)
  var=classifier.predict(pre)
  print("The probability of finding certain minerals at this location are as follows:\n")
  if(var=="Laterite"):   
    da={"minerals" : ["Quartz","Kaolinite","Nontronite","Goethite","Hematite","Nickel"],
    "values" : [36.06,0.21,18.77,27.43,2.81,1.1]
    }
    sns.set(font_scale= 1)
    plt.figure(figsize=(15,7))
    ax = sns.barplot(x="minerals",y="values",data=da,ci=None)
    for p in ax.patches:
      ax.annotate('{:.1f}'.format(p.get_height()), (p.get_x()+0.25, p.get_height()+0.01))
    ax.set_xlabel("Minerals", fontsize = 15)
    ax.set_ylabel("Percentage probability", fontsize = 15)
    ax.set_title("Probability pecentage of Minerals",fontsize=15)
    plt.show()

  elif(var=="Rajahmundry Sandstone"):

    da={"minerals" : ["Quartz","K-feldspar","Calcite","Chlorite"],
    "values" : [58, 3, 5, 1]
    }
    sns.set(font_scale= 1)
    plt.figure(figsize=(15,7))
    ax = sns.barplot(x="minerals",y="values",data=da,ci=None)
    for p in ax.patches:
      ax.annotate('{:.1f}'.format(p.get_height()), (p.get_x()+0.25, p.get_height()+0.01))
    ax.set_xlabel("Minerals", fontsize = 15)
    ax.set_ylabel("Percentage probability", fontsize = 15)
    ax.set_title("Probability pecentage of Minerals",fontsize=15)
    plt.show()

  elif(var=="Tirupati Sandstone"):

    da={"minerals" : ["Cement","Quartz","Calcite"],
    "values" : [50.8,25.4,4.4]
    }
    sns.set(font_scale= 1)
    plt.figure(figsize=(15,7))
    ax = sns.barplot(x="minerals",y="values",data=da,ci=None)
    for p in ax.patches:
      ax.annotate('{:.1f}'.format(p.get_height()), (p.get_x()+0.25, p.get_height()+0.01))
    ax = sns.barplot(minerals, values)
    ax.set_xlabel("Minerals", fontsize = 15)
    ax.set_ylabel("Percentage probability", fontsize = 15)
    ax.set_title("Probability pecentage of Minerals",fontsize=15)
    plt.show()
   
  elif(var=="Raghavapuram Shale"):

    da={"minerals" : ["Kaolinite","Quartz","Chlorite", "Smectite/ Illite", "Feldspar"],
    "values" : [59.8, 26.7, 8.7, 3.5,1.3]
    }
    sns.set(font_scale= 1)
    plt.figure(figsize=(15,7))
    ax = sns.barplot(x="minerals",y="values",data=da,ci=None)
    for p in ax.patches:
      ax.annotate('{:.1f}'.format(p.get_height()), (p.get_x()+0.25, p.get_height()+0.01))
    ax.set_xlabel("Minerals", fontsize = 15)
    ax.set_ylabel("Percentage probability", fontsize = 15)
    ax.set_title("Probability pecentage of Minerals",fontsize=15)
    plt.show()

  elif(var=="Gollapalli Sandstone"):
    da={"minerals" : ["Ouartz","Sericite","Calcite", "Mica", "Iron", "Charcoal"],
    "values" : [73.39, 13.20 , 5.20 , 3.60, 1.20, 3.20]
    }
    sns.set(font_scale= 1)
    plt.figure(figsize=(15,7))
    ax = sns.barplot(x="minerals",y="values",data=da,ci=None)
    for p in ax.patches:
      ax.annotate('{:.1f}'.format(p.get_height()), (p.get_x()+0.25, p.get_height()+0.01))
    ax.set_xlabel("Minerals", fontsize = 15)
    ax.set_ylabel("Percentage probability", fontsize = 15)
    ax.set_title("Probability pecentage of Minerals",fontsize=15)
    plt.show()

  elif(var=="Avanigedda clay"):
      da={"minerals" : ["Illite","Kaolinite","Chlorite", "Quartz", "Hematite"],
      "values" : [23-37, 6-12 ,3-5, 30-45, 3-6 ]
      }
      ax = sns.barplot(x="minerals",y="values",data=da,ci=None)
      sns.set(font_scale= 1)
      plt.figure(figsize=(15,7))
      for p in ax.patches:
       ax.annotate('{:.1f}'.format(p.get_height()), (p.get_x()+0.25, p.get_height()+0.01))
      ax.set_xlabel("Minerals", fontsize = 15)
      ax.set_ylabel("Percentage probability", fontsize = 15)
      ax.set_title("Probability pecentage of Minerals", fontsize=15)
      plt.show()

  elif(var=="Avanigedda siltyclay"):
      da={"minerals" : ["Illite"],
      "values" : [26]}
      sns.set(font_scale= 1)
      plt.figure(figsize=(15,7))
      ax = sns.barplot(x="minerals",y="values",data=da,ci=None)
      for p in ax.patches:
        ax.annotate('{:.1f}'.format(p.get_height()), (p.get_x()+0.25, p.get_height()+0.01))
      ax.set_xlabel("Minerals", fontsize = 15)
      ax.set_ylabel("Percentage probability", fontsize = 15)
      ax.set_title("Probability pecentage of Minerals",fontsize=15)
      plt.show()

  elif(var=="Kaikalur clay"):   
      #im = Image.open(r"C:\Users\Nitin\Desktop\cem")
      print("Cement would be found here , coupled with white cement\n")
  
  elif(var=="quart"):
      da={"minerals" : ["Quartz"],
      "values" : [100]
      }
      ax = sns.barplot(x="minerals",y="values",data=da,ci=None)
      sns.set(font_scale= 1)
      plt.figure(figsize=(15,7))
      for p in ax.patches:
       ax.annotate('{:.1f}'.format(p.get_height()), (p.get_x()+0.25, p.get_height()+0.01))
      ax.set_xlabel("Minerals", fontsize = 15)
      ax.set_ylabel("Percentage probability", fontsize = 15)
      ax.set_title("Probability pecentage of Minerals", fontsize=15)
      plt.show()
  
  elif(var=="undiff"):
      da={"minerals" : ["Smectite", "Vermiculite", "Limonite"," Pyroxene"],
      "values" : [16, 14, 18.1, 6.8]
      }
      ax = sns.barplot(x="minerals",y="values",data=da,ci=None)
      sns.set(font_scale= 1)
      plt.figure(figsize=(15,7))
      for p in ax.patches:
       ax.annotate('{:.1f}'.format(p.get_height()), (p.get_x()+0.25, p.get_height()+0.01))
      ax.set_xlabel("Minerals", fontsize = 15)
      ax.set_ylabel("Percentage probability", fontsize = 15)
      ax.set_title("Probability pecentage of Minerals", fontsize=15)
      plt.show()    

  elif(var=="dolomite"):
      da={"minerals" : ["Dolomite"],
      "values" : [100]
      }
      ax = sns.barplot(x="minerals",y="values",data=da,ci=None)
      sns.set(font_scale= 1)
      plt.figure(figsize=(15,7))
      for p in ax.patches:
       ax.annotate('{:.1f}'.format(p.get_height()), (p.get_x()+0.25, p.get_height()+0.01))
      ax.set_xlabel("Minerals", fontsize = 15)
      ax.set_ylabel("Percentage probability", fontsize = 15)
      ax.set_title("Probability pecentage of Minerals", fontsize=15)
      plt.show()

  elif(var=="granite"):
      da={"minerals" : ["Quartz", "Alkali Feldspar","Plagiociase","Biotite","Chlorite"],
      "values" : [40.6, 25.2, 31, 2.2, 1.1]
      }
      ax = sns.barplot(x="minerals",y="values",data=da,ci=None)
      sns.set(font_scale= 1)
      plt.figure(figsize=(15,7))
      for p in ax.patches:
       ax.annotate('{:.1f}'.format(p.get_height()), (p.get_x()+0.25, p.get_height()+0.01))
      ax.set_xlabel("Minerals", fontsize = 15)
      ax.set_ylabel("Percentage probability", fontsize = 15)
      ax.set_title("Probability pecentage of Minerals", fontsize=15)
      plt.show()  

  elif(var=="not"):
      print("There is almost negligible probability of finding any mineral") 

  elif(var=="aeol"):
      da={"minerals" : ["Quartz","Illite","Kaolinite","Chlorite","Hematite"],
      "values" : [30, 23, 6, 3, 3]
      }
      ax = sns.barplot(x="minerals",y="values",data=da,ci=None)
      sns.set(font_scale= 1)
      plt.figure(figsize=(15,7))
      for p in ax.patches:
       ax.annotate('{:.1f}'.format(p.get_height()), (p.get_x()+0.25, p.get_height()+0.01))
      ax.set_xlabel("Minerals", fontsize = 15)
      ax.set_ylabel("Percentage probability", fontsize = 15)
      ax.set_title("Probability pecentage of Minerals", fontsize=15)
      plt.show()  

  elif(var=="amph"):
      da={"minerals" : ["Silica","Aluminium Oxide","Quick Lime","Ferrous Oxide"],
      "values" : [48.41, 15.05, 11.4, 11.07]
      }
      ax = sns.barplot(x="minerals",y="values",data=da,ci=None)
      sns.set(font_scale= 1)
      plt.figure(figsize=(15,7))
      for p in ax.patches:
       ax.annotate('{:.1f}'.format(p.get_height()), (p.get_x()+0.25, p.get_height()+0.01))
      ax.set_xlabel("Minerals", fontsize = 15)
      ax.set_ylabel("Percentage probability", fontsize = 15)
      ax.set_title("Probability pecentage of Minerals", fontsize=15)
      plt.show() 

  elif(var=="ferruginous"):
      da={"minerals" : ["Silica","Ferric Oxide","Aluminium Oxide"],
      "values" : [42.45, 20, 8.5]
      }
      ax = sns.barplot(x="minerals",y="values",data=da,ci=None)
      sns.set(font_scale= 1)
      plt.figure(figsize=(15,7))
      for p in ax.patches:
       ax.annotate('{:.1f}'.format(p.get_height()), (p.get_x()+0.25, p.get_height()+0.01))
      ax.set_xlabel("Minerals", fontsize = 15)
      ax.set_ylabel("Percentage probability", fontsize = 15)
      ax.set_title("Probability pecentage of Minerals", fontsize=15)
      plt.show()   

  elif(var=="quartzite"):
      da={"minerals" : ["Quartz","Magnetite","Hematite"],
      "values" : [29.5, 34, 1.73]
      }
      ax = sns.barplot(x="minerals",y="values",data=da,ci=None)
      sns.set(font_scale= 1)
      plt.figure(figsize=(15,7))
      for p in ax.patches:
       ax.annotate('{:.1f}'.format(p.get_height()), (p.get_x()+0.25, p.get_height()+0.01))
      ax.set_xlabel("Minerals", fontsize = 15)
      ax.set_ylabel("Percentage probability", fontsize = 15)
      ax.set_title("Probability pecentage of Minerals", fontsize=15)
      plt.show()  

  elif(var=="marble"):
      da={"minerals" : ["Dolomite","Calcite"],
      "values" : [96.98, 3.02]
      }
      ax = sns.barplot(x="minerals",y="values",data=da,ci=None)
      sns.set(font_scale= 1)
      plt.figure(figsize=(15,7))
      for p in ax.patches:
       ax.annotate('{:.1f}'.format(p.get_height()), (p.get_x()+0.25, p.get_height()+0.01))
      ax.set_xlabel("Minerals", fontsize = 15)
      ax.set_ylabel("Percentage probability", fontsize = 15)
      ax.set_title("Probability pecentage of Minerals", fontsize=15)
      plt.show() 

  elif(var=="phyllite"):
      da={"minerals" : ["Quartz","Muscovite","Micro Lime","Kaolinite"],
      "values" : [50.8, 6.1, 2.0,3.07]
      }
      ax = sns.barplot(x="minerals",y="values",data=da,ci=None)
      sns.set(font_scale= 1)
      plt.figure(figsize=(15,7))
      for p in ax.patches:
       ax.annotate('{:.1f}'.format(p.get_height()), (p.get_x()+0.25, p.get_height()+0.01))
      ax.set_xlabel("Minerals", fontsize = 15)
      ax.set_ylabel("Percentage probability", fontsize = 15)
      ax.set_title("Probability pecentage of Minerals", fontsize=15)
      plt.show()

# %%
Mineral_probability(215,12,250,2)
# Out:
# The probability of finding certain minerals at this location are as follows:
# c:\Users\user\AppData\Local\Programs\Python\Python39\lib\site-packages\sklearn\base.py:493: FutureWarning: The feature names should match those that were passed during fit. Starting version 1.2, an error will be raised.
# Feature names unseen at fit time:
# - Elevation (in m)
# Feature names seen at fit time, yet now missing:
# - Elevation
#
#   warnings.warn(message, FutureWarning)

# %%
y_pred=classifier.predict(X_test)

# %%
from sklearn.metrics import confusion_matrix

# %%
cm=confusion_matrix(y_test, y_pred)

import seaborn as sns
import matplotlib.pyplot as plt
### Confusion Matrix
from sklearn.metrics import confusion_matrix
## Get Class Labels
# Plot confusion matrix in a beautiful manner
fig = plt.figure(figsize=(10, 8))
ax= plt.subplot()
sns.heatmap(cm, annot=True, ax = ax, fmt = 'g'); #annot=True to annotate cells
# labels, title and ticks
ax.set_xlabel('Predicted', fontsize=20)
plt.xticks(rotation=90)
ax.set_ylabel('True', fontsize=20)
plt.yticks(rotation=0)
plt.title('Confusion Matrix', fontsize=20)
plt.savefig('ConMat24.png')
plt.show()
